# %% [markdown]
# <a href="https://colab.research.google.com/github/Bunny825/Logistic_Regression/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
class Logistic_Regression:
    def __init__(self, learning_rate, no_of_iterations):
        self.learning_rate = learning_rate
        self.no_of_iterations = no_of_iterations

    def fit(self, x, y):
        self.m, self.n = x.shape
        self.w = np.zeros(self.n)
        self.b = 0
        self.x = x
        self.y = y
        for i in range(self.no_of_iterations):
            self.update_weights()

    def update_weights(self):
        z = self.x.dot(self.w) + self.b
        y_hat = 1 / (1 + np.exp(-z))
        dw = (1 / self.m) * np.dot(self.x.T, (y_hat - self.y))
        db = (1 / self.m) * np.sum(y_hat - self.y)
        self.w = self.w - self.learning_rate * dw
        self.b = self.b - self.learning_rate * db

    def predict(self, x):
        z = x.dot(self.w) + self.b  # Use the input `x` for prediction
        y_pred = 1 / (1 + np.exp(-z))
        y_pred = np.where(y_pred > 0.5, 1, 0)
        return y_pred

# %% [markdown]
# Import all the required dependencies.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# Import and have an overview of the data

# %%
diabetes=pd.read_csv("/content/diabetes.csv")
diabetes.shape
# Out:
# (768, 9)

# %%
diabetes.head()
#observe that all the values in a column are not in the same range
#0 in outcome is -ve for diabetes
#1 in outcome is +ve for diabetes
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Obseve the difference in different aspects of the data by grouping it with targert variable i.e Outcome

# %%
diabetes.groupby("Outcome").mean()
#observe in the mean value of pregnencies is grater in diabetic patients and same analogy
#with glucode,BP,skin thickness and Insulin .So understand that diabetes is
#directly proportional with all these features
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# Comparing the number of diabetes vs non-diabetes patients

# %%
diabetes["Outcome"].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
sns.countplot(data=diabetes,x="Outcome")
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %% [markdown]
# Dividing the data into features and Outcomes to predict

# %%
x=diabetes.drop(columns="Outcome",axis=1)
y=diabetes["Outcome"]
print(x)
print(y)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %% [markdown]
# Standardising the data so that all the values in all the columns in the data will be in the same range which will be a great help to the machine

# %%
scaler=StandardScaler()
scaler.fit(x)
x=scaler.transform(x)
print(x)
print(y)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# Splitting the data into Training and Tesing data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=2,test_size=0.2,stratify=y)
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# Building the model

# %%
model=Logistic_Regression(learning_rate=0.01,no_of_iterations=1000)
model.fit(x_train,y_train)

# %% [markdown]
# Predicing and Finding accuracy

# %%
train_predicted=model.predict(x_train)
train_score=accuracy_score(train_predicted,y_train)
print(train_score)


test_predicted = model.predict(x_test)
test_score=accuracy_score(test_predicted,y_test)
print(test_score)
# Out:
# 0.7785016286644951
# 0.7597402597402597

# %% [markdown]
# Function to predict for unknown inputs

# %%
def predict_new(input):
    input = np.asarray(input)
    input = input.reshape(1, -1)
    input = scaler.transform(input)  # Correctly scale the input
    pred = model.predict(input)
    if pred[0] == 0:
        print("The patient is non-diabetic")
    else:
        print("The patient is diabetic")

# %%
predict_new([0,137,40,35,168,43.1,2.288,33])
predict_new([3,126,88,41,235,39.3,0.704,27])
# Out:
# The patient is diabetic
# The patient is non-diabetic
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
